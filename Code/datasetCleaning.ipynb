# %%
import pandas as pd

# %%
df_spotify= pd.read_csv('SpotifyFeatures.csv')
df_lastfm=pd.read_csv('Last.fm_data.csv')

# %%
df_spotify.head()
# Out:
#    genre        artist_name                        track_name  \
# 0  Movie     Henri Salvador       C'est beau de faire un Show
# 1  Movie  Martin & les fées  Perdu d'avance (par Gad Elmaleh)
# 2  Movie    Joseph Williams    Don't Let Me Be Lonely Tonight
# 3  Movie     Henri Salvador    Dis-moi Monsieur Gordon Cooper
# 4  Movie       Fabien Nataf                         Ouverture
#
#                  track_id  popularity  acousticness  danceability  \
# 0  0BRjO6ga9RKCKjfDqeFgWV           0         0.611         0.389
# 1  0BjC1NfoEOOusryehmNudP           1         0.246         0.590
# 2  0CoSDzoNIKCRs124s9uTVy           3         0.952         0.663
# 3  0Gc6TVm52BwZD07Ki6tIvf           0         0.703         0.240
# 4  0IuslXpMROHdEPvSl1fTQK           4         0.950         0.331
#
#    duration_ms  energy  instrumentalness key  liveness  loudness   mode  \
# 0        99373   0.910             0.000  C#    0.3460    -1.828  Major
# ...

# %%
df_lastfm.head()
# Out:
#    Unnamed: 0 Username           Artist                          Track  \
# 0           0  Babs_05  Isobel Campbell     The Circus Is Leaving Town
# 1           1  Babs_05  Isobel Campbell                   Dusty Wreath
# 2           2  Babs_05  Isobel Campbell     Honey Child What Can I Do?
# 3           3  Babs_05  Isobel Campbell  It's Hard To Kill A Bad Thing
# 4           4  Babs_05  Isobel Campbell                Saturday's Gone
#
#                        Album         Date    Time
# 0  Ballad of the Broken Seas  31 Jan 2021   23:36
# 1  Ballad of the Broken Seas  31 Jan 2021   23:32
# 2  Ballad of the Broken Seas  31 Jan 2021   23:28
# 3  Ballad of the Broken Seas  31 Jan 2021   23:25
# 4  Ballad of the Broken Seas  31 Jan 2021   23:21

# %%
display(df_lastfm.columns)
# Out:
# Index(['Unnamed: 0', 'Username', 'Artist', 'Track', 'Album', 'Date', 'Time'], dtype='object')

# %%
df_lastfm.drop(['Album','Date','Time'],axis=1,inplace=True)

# %%
display(df_lastfm.columns)
# Out:
# Index(['Username', 'Artist', 'Track'], dtype='object')

# %%
display(df_spotify.columns)
# Out:
# Index(['genre', 'artist_name', 'track_name', 'track_id', 'popularity',
#        'acousticness', 'danceability', 'duration_ms', 'energy',
#        'instrumentalness', 'key', 'liveness', 'loudness', 'mode',
#        'speechiness', 'tempo', 'time_signature', 'valence'],
#       dtype='object')

# %%
df_lastfm = df_lastfm.rename(columns={'Artist': 'artist_name', 'Track': 'track_name'})

# %%
merged_data = pd.merge(df_lastfm, df_spotify, on=['artist_name', 'track_name'], how='inner')

# %%
merged_data.to_csv('merged_data.csv', index=False)

# %%
merged_data.head()
# Out:
#   Username      artist_name track_name    genre                track_id  \
# 0  Babs_05  Kacey Musgraves  Slow Burn    Dance  6ET9kf9riLETWs9lePUEAI
# 1  Babs_05  Kacey Musgraves  Slow Burn      Pop  6ET9kf9riLETWs9lePUEAI
# 2  Babs_05  Kacey Musgraves  Slow Burn  Country  6ET9kf9riLETWs9lePUEAI
# 3  Babs_05      Salt-N-Pepa    Push It    Dance  0TT7wJiEYD5GAeJfSR1ETX
# 4  Babs_05      Salt-N-Pepa    Push It  Hip-Hop  0TT7wJiEYD5GAeJfSR1ETX
#
#    popularity  acousticness  danceability  duration_ms  energy  \
# 0          73       0.46200         0.555       246133    0.43
# 1          74       0.46200         0.555       246133    0.43
# 2          73       0.46200         0.555       246133    0.43
# 3          66       0.00684         0.926       272133    0.60
# 4          67       0.00684         0.926       272133    0.60
#
#    instrumentalness key  liveness  loudness   mode  speechiness    tempo  \
# 0          0.000191   D    0.0869    -9.105  Major       0.0295  147.613
# ...

# %%
merged_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 65888 entries, 0 to 65887
# Data columns (total 19 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Username          65888 non-null  object
#  1   artist_name       65888 non-null  object
#  2   track_name        65888 non-null  object
#  3   genre             65888 non-null  object
#  4   track_id          65888 non-null  object
#  5   popularity        65888 non-null  int64
#  6   acousticness      65888 non-null  float64
#  7   danceability      65888 non-null  float64
#  8   duration_ms       65888 non-null  int64
#  9   energy            65888 non-null  float64
#  10  instrumentalness  65888 non-null  float64
#  11  key               65888 non-null  object
#  12  liveness          65888 non-null  float64
#  13  loudness          65888 non-null  float64
#  14  mode              65888 non-null  object
#  15  speechiness       65888 non-null  float64
# ...

# %%
print(merged_data.isnull().sum())
# Out:
# Username            0
# artist_name         0
# track_name          0
# genre               0
# track_id            0
# popularity          0
# acousticness        0
# danceability        0
# duration_ms         0
# energy              0
# instrumentalness    0
# key                 0
# liveness            0
# loudness            0
# mode                0
# speechiness         0
# tempo               0
# time_signature      0
# valence             0
# dtype: int64

# %%
display(merged_data.columns)
# Out:
# Index(['Username', 'artist_name', 'track_name', 'genre', 'track_id',
#        'popularity', 'acousticness', 'danceability', 'duration_ms', 'energy',
#        'instrumentalness', 'key', 'liveness', 'loudness', 'mode',
#        'speechiness', 'tempo', 'time_signature', 'valence'],
#       dtype='object')

# %%
song_data=merged_data.drop(['duration_ms', 'key', 'mode', 'time_signature'],axis=1)

# %%
display(song_data.columns)
# Out:
# Index(['Username', 'artist_name', 'track_name', 'genre', 'track_id',
#        'popularity', 'acousticness', 'danceability', 'energy',
#        'instrumentalness', 'liveness', 'loudness', 'speechiness', 'tempo',
#        'valence'],
#       dtype='object')

# %%
song_data.to_csv('songs_data.csv', index=False)

# %%
import matplotlib.pyplot as plt
import seaborn as sns


plt.figure(figsize=(16, 10))
plt.suptitle('Distribution of Key Audio Features', fontsize=16)

features_to_plot = ['popularity', 'danceability', 'energy', 'acousticness', 'valence', 'loudness']
for i, feature in enumerate(features_to_plot, 1):
    plt.subplot(2, 3, i)
    sns.histplot(songs_df[feature], kde=True, bins=30)
    plt.title(f'Distribution of {feature.capitalize()}')

plt.tight_layout(rect=[0, 0.03, 1, 0.95])
plt.show()

# %%
import pandas as pd

# Load the dataset
df = pd.read_csv('songs_data.csv')

df_no_duplicates = df.drop_duplicates(subset=['track_name'], keep='first')
duplicate_rows = df_no_duplicates.duplicated().sum()
# if duplicate_rows == 0:
#     print("No fully duplicate rows found in the cleaned data.")
# else:
#     print(f"{duplicate_rows} fully duplicate rows were found and will be removed.")
#     df_no_duplicates.drop_duplicates(inplace=True)

# df_transposed = df_no_duplicates.T
# duplicate_columns = df_transposed.duplicated().sum()

# if duplicate_columns == 0:
#     print("No duplicate columns found in the data.\n")
# else:
#     print(f"{duplicate_columns} duplicate columns were found and will be removed.")
#     df_no_duplicates = df_no_duplicates.T.drop_duplicates().T

df_no_duplicates.to_csv('songs_data_cleaned.csv', index=False)

df_no_duplicates.shape
# Out:
# (10722, 15)
